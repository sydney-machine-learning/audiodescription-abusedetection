# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(asctime)s - %(message)s')

import bs4
import requests
import pandas as pd
import numpy as np
from tqdm import tqdm

import time
from io import StringIO
import os

import data_extraction as da
import modelling as md

import plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
av_base_url = 'https://audiovault.net/movies'
df_list = []

for ii in range(1, 130):
    url = f'{av_base_url}?page={str(ii)}'
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table')
    df_list.append(pd.read_html(StringIO(str(table)))[0])
    time.sleep(0.5)

raw_df = pd.concat(df_list)

# %%
df = raw_df.copy()
df['year_primary'] = df['Name'].str.extract('\((\d{4})\)')[0]
df['year_secondary'] = df['Name'].str.extract('(\d{4})')[0]
df['year'] = np.where(df['year_primary'].notna(), df['year_primary'], df['year_secondary'])
df['year'] = np.where(df['year'].notna(), df['year'], 4000).astype(int)
df['cleaned_name'] = df['Name'].str.replace('\[[\w\s]*\]', '', regex=True).str.replace('\(\d{4}\)', '', regex=True).str.strip()
df = df[df.year.ge(2011)]
df = df.drop_duplicates(subset='cleaned_name')

df.to_parquet(os.path.join(da.audio_vault_dir, 'av_all_films.parquet'))

# %%
pd.read_parquet(os.path.join(da.audio_vault_dir, 'av_all_films.parquet'))
# Out:
#        ID                                      Name  Download year_primary  \
# 0   22977  'Tis the Season to be Irish (2024) [TTS]  Download         2024
# 1   14462   'Twas The Fight Before Christmas (2021)  Download         2021
# 2    2790                       #RealityHigh (2017)  Download         2017
# 3   21163                              #Xmas (2023)  Download         2023
# 4   10442                            1 Night (2016)  Download         2016
# ..    ...                                       ...       ...          ...
# 25  17036                           Zone 414 (2021)  Download         2021
# 26  18193                          Zookeeper (2011)  Download         2011
# 29  17366                   Zoolander 2 (2016) [UK]  Download         2016
# 31   8896                               Zoom (2015)  Download         2015
# 33   8898           Zootopia aka Zootropolis (2016)  Download         2016
#
#    year_secondary  year                      cleaned_name
# 0            2024  2024       'Tis the Season to be Irish
# 1            2021  2021  'Twas The Fight Before Christmas
# 2            2017  2017                      #RealityHigh
# 3            2023  2023                             #Xmas
# 4            2016  2016                           1 Night
# ..            ...   ...                               ...
# 25           2021  2021                          Zone 414
# 26           2011  2011                         Zookeeper
# 29           2016  2016                       Zoolander 2
# 31           2015  2015                              Zoom
# 33           2016  2016          Zootopia aka Zootropolis
#
# [7048 rows x 7 columns]

# %%
acb_base_url = 'https://www.classification.gov.au/titles/'
acb_df = da.get_acb_film_ratings()
acb_df['url_title'] = acb_df['url'].str.replace(acb_base_url, '').str.replace('\-\d{1,2}$', '', regex=True)

# %%
stop_words = ['the', 'of', 'a', 'in', 'up', 'at', 'is', 'to', 'by', 'this', 'an']
stop_char = ["'", ',', '.', '#']

# %%
acb_df['test_url'] = acb_df['movie'].str.lower().str.split(' ').apply(lambda x: '-'.join(y for y in x if not y in stop_words))

for char in stop_char:
    acb_df['test_url'] = acb_df['test_url'].str.replace(char, '')
acb_df['test_url'] = acb_df['test_url'].str.replace('-{2,}', '-', regex=True)

# %%
df['search_url'] = df['cleaned_name'].str.lower().str.split(' ').apply(lambda x: '-'.join(y for y in x if not y in stop_words))

for char in stop_char:
    df['search_url'] = df['search_url'].str.replace(char, '')
    df['search_url'] = df['search_url'].str.replace('-{2,}', '-', regex=True)

# %%
# The following function was created with assistance from ChatGPT
def get_matrix_results(matrix, movie_info: dict):
    column_names = ['none', 'very mild', 'mild', 'moderate', 'strong', 'high']
    for ii, row in enumerate(matrix):
        # Find each of the 6 columns and iterate through those
        for jj, cell in enumerate(row.find_all('span', class_='impact-matrix__impact')):
            label_span = cell.find('span', class_='impact-matrix__rating-label')
            # When category gets film rating, they display the image of the classification icon (not just coloured circle)
            img_tag = cell.find('img')
            
            if label_span or img_tag:
                impact_column = column_names[jj]
        
        movie_info[md.full_cat_cols[ii]] = impact_column

    return movie_info

# The following function was created with assistance from ChatGPT
def get_metadata_table(soup, movie_info: dict):
    metadata_table = soup.find(class_='view-classification-title-nodes')

    if metadata_table is not None:

        for div in metadata_table.select('.views-field'):
            key = div.find('span', class_='views-label').get_text(strip=True)
            text = div.find('div', class_='field-content').get_text(strip=True)
            if text:
                movie_info[key] = text

    return movie_info


def check_eligibile_film(soup, movie_info: dict):

    access_denied = 'Access denied' in soup.text
    is_film = 'Category' in movie_info and movie_info['Category'] == 'Films'
    is_advertising = 'Category detail' in movie_info and 'Advertising' in movie_info['Category detail']
    is_current = False
    has_impact_table = len(soup.find_all('li', class_='impact-matrix__item')) in [6, 12]

    if 'Classification date' in movie_info and movie_info['Classification date'] != 'Not Specified':
        try:
            date = pd.to_datetime(movie_info['Classification date'])
            is_current = date > pd.to_datetime('2012-06-01')
        except:
            logging.info(f'Invalid datetime: {movie_info["Classification date"]}')

    found_eligible_film = False if access_denied else (is_film and is_current and has_impact_table and not is_advertising)

    return found_eligible_film

# %%
record_list = []
outcome = []

for ii, search_url in enumerate(df['search_url']):

    # TODO: replace with tdqm and ensure results are saved on failure
    # TODO: retain year from AV and verify as part of eligibility (with reasonable gap)
    if ii % 50 == 0:
        logging.info(f'{ii} / {df.shape[0]}')

    url = f'{acb_base_url}{search_url}'
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.content, 'html.parser')
    movie_info = {}

    if 'Page not found' in soup.text:
        record_list.append({})
        outcome.append('page-not-found')
        continue

    # Extract metadata
    movie_info = get_metadata_table(soup, movie_info)

    # If listing is from before additional data dates or is not a film (e.g. game), keep trying until you find one or run out
    # As there can be multiple listings with the same name
    jj = 0

    found_eligible_film = check_eligibile_film(soup, movie_info)
    while not found_eligible_film:
        time.sleep(1)
        url = f'{acb_base_url}{search_url}-{jj}'
        response = requests.get(url)
        soup = bs4.BeautifulSoup(response.content, 'html.parser')

        if 'Page not found' in soup.text:
            # Take previous url (as that is the data that will be used)
            if jj != 0:
                url = f'{acb_base_url}{search_url}-{jj-1}'
            else:
                url = f'{acb_base_url}{search_url}'

            record_list.append({})
            outcome.append('no-eligible-film-found')
            break

        movie_info = get_metadata_table(soup, movie_info)
        found_eligible_film = check_eligibile_film(soup, movie_info)
        jj += 1

    if 'Page not found' in soup.text:
        continue

    movie_info['url'] = url

    # Find and iterate through 6 rows in classification table
    matrix = soup.find_all('li', class_='impact-matrix__item')

    # Check if page has impact table
    if matrix is None:
        record_list.append({})
        outcome.append('matrix-not-found')
        continue
    
    # Check size of impact table matches known patterns
    if len(matrix) == 6:
        movie_info = get_matrix_results(matrix, movie_info)
        outcome.append('success')
    elif len(matrix) == 12:
        # ACB tables can be doubled up due to mistakes in data
        movie_info = get_matrix_results(matrix[::2], movie_info)
        outcome.append('matrix-doubled-1')

        if all(val == 'none' for key, val in movie_info.items() if key in md.full_cat_cols):
            movie_info = get_matrix_results(matrix[1::2], movie_info)
            outcome[-1] = 'matrix-doubled-2'

    else:
        outcome.append('matrix-not-6-or-12')

    time.sleep(1)
    record_list.append(movie_info)

cat_df = pd.DataFrame(record_list)
cat_df['outcome'] = outcome
# Out:
# INFO - 2025-07-01 17:52:02,133 - 0 / 7048
# INFO - 2025-07-01 17:52:51,451 - 50 / 7048
# INFO - 2025-07-01 17:53:52,356 - 100 / 7048
# INFO - 2025-07-01 17:54:47,895 - 150 / 7048
# INFO - 2025-07-01 17:55:56,997 - 200 / 7048
# INFO - 2025-07-01 17:56:49,485 - 250 / 7048
# INFO - 2025-07-01 17:58:15,755 - 300 / 7048
# INFO - 2025-07-01 18:00:23,070 - 350 / 7048
# INFO - 2025-07-01 18:01:51,786 - 400 / 7048
# INFO - 2025-07-01 18:03:46,891 - 450 / 7048
# INFO - 2025-07-01 18:05:36,455 - 500 / 7048
# INFO - 2025-07-01 18:07:13,751 - 550 / 7048
# INFO - 2025-07-01 18:08:54,721 - 600 / 7048
# INFO - 2025-07-01 18:10:31,509 - 650 / 7048
# INFO - 2025-07-01 18:12:03,183 - 700 / 7048
# INFO - 2025-07-01 18:14:09,770 - 750 / 7048
# INFO - 2025-07-01 18:15:19,807 - 800 / 7048
# INFO - 2025-07-01 18:17:10,415 - 850 / 7048
# INFO - 2025-07-01 18:20:18,764 - 900 / 7048
# INFO - 2025-07-01 18:22:04,611 - 950 / 7048
# INFO - 2025-07-01 18:23:32,990 - 1000 / 7048
# INFO - 2025-07-01 18:25:06,925 - 1050 / 7048
# INFO - 2025-07-01 18:26:49,650 - 1100 / 7048
# INFO - 2025-07-01 18:28:54,896 - 1150 / 7048
# INFO - 2025-07-01 18:30:14,118 - 1200 / 7048
# INFO - 2025-07-01 18:31:01,991 - 1250 / 7048
# INFO - 2025-07-01 18:31:54,790 - 1300 / 7048
# INFO - 2025-07-01 18:34:53,840 - 1350 / 7048
# INFO - 2025-07-01 18:36:46,156 - 1400 / 7048
# INFO - 2025-07-01 18:38:14,602 - 1450 / 7048
# INFO - 2025-07-01 18:39:44,926 - 1500 / 7048
# INFO - 2025-07-01 18:41:20,016 - 1550 / 7048
# INFO - 2025-07-01 18:43:01,448 - 1600 / 7048
# INFO - 2025-07-01 18:44:29,241 - 1650 / 7048
# INFO - 2025-07-01 22:24:24,149 - 6600 / 7048
# INFO - 2025-07-01 22:26:25,704 - 6650 / 7048
# INFO - 2025-07-01 22:29:30,312 - 6700 / 7048
# INFO - 2025-07-01 22:31:02,864 - 6750 / 7048
# INFO - 2025-07-01 22:32:58,205 - 6800 / 7048
# INFO - 2025-07-01 22:34:05,638 - 6850 / 7048
# INFO - 2025-07-01 22:35:08,311 - 6900 / 7048
# INFO - 2025-07-01 22:37:09,847 - 6950 / 7048
# INFO - 2025-07-01 22:38:34,350 - 7000 / 7048

# %%
cat_df['outcome'] = outcome
df = df.reset_index(drop=True)
df_w_ratings = pd.concat([df, cat_df], axis=1)
df_w_ratings.to_parquet(os.path.join('data', 'av_films_with_ratings.parquet'))

# %%
df_w_ratings = pd.read_parquet(os.path.join('data', 'av_films_with_ratings.parquet'))
df_w_ratings['duration_num'] = df_w_ratings['Duration'].str.extract(r'(\d+)').astype(float)
df_w_ratings['strong_count'] = df_w_ratings[md.full_cat_cols].isin(['strong', 'high']).sum(axis=1)
df_w_ratings['moderate_count'] = df_w_ratings[md.full_cat_cols].isin(['moderate', 'strong', 'high']).sum(axis=1)
df_w_ratings['url_ending'] = df_w_ratings['url'].str.split('/').apply(lambda x: x[-1] if x is not None else '')

# %%
ord_acb_df = df_w_ratings.copy()
for col in md.full_cat_cols:
    ord_acb_df[col] = md.convert_col_to_ordinal(ord_acb_df[col], compact=True)

melt_df = pd.melt(ord_acb_df[ord_acb_df.themes.ne(-1)], ['cleaned_name'], md.full_cat_cols)
melt_df['Category'] = melt_df['variable'].str.title().str.replace('_', ' ')
g = sns.countplot(melt_df, x='Category', hue='value')
plt.ylabel('Count')
txt_labels = ['Very Mild or None', 'Mild', 'Moderate', 'Strong or High']
plt.xticks(fontsize=6)
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Severity', ncol=2, txt_labels=txt_labels)
plotting.savefig('ACB Overall Distribution')
plt.show()

# %%
ratings_cols = [
    'Name', 'url_ending', 'Classification', 'Consumer advice', 'Category', 'Category detail', 'Media type',
    'Director/Creator', 'Producer', 'Production company', 'Applicant', 'Duration', 'duration_num', 'strong_count'
]

outside_classifiers = [
    'Film External Approved Decision received by API',
    'External API',
    'Accredited Classifier Decision - Film',
    'Film - Netflix Classification Tool',
    'Film - Spherex Classification Tool',
    'Film - Amazon Classification Tool',
    'Decision made by Broadcaster',
    'Film Other',
]

# %%
df_w_ratings[df_w_ratings['Category detail'].isin(outside_classifiers)]
# Out:
#          ID                                               Name  Download  \
# 2      2790                                #RealityHigh (2017)  Download
# 4     10442                                     1 Night (2016)  Download
# 6     18512  10 Days of a Good Man (2023) [Turkish Descript...  Download
# 13    10521                       12 Dates of Christmas (2011)  Download
# 16    15032                 12 Gifts Of Christmas (2015) [TTS]  Download
# ...     ...                                                ...       ...
# 7016  23193                  Your Friend, Nate Bargatze (2024)  Download
# 7018  23381                                Your Monster (2024)  Download
# 7019  18318                          Your Place or Mine (2023)  Download
# 7021  18667                 Yours Sincerely, Kanan Gill (2020)  Download
# 7032  18743                                        Zion (2018)  Download
#
#      year_primary year_secondary  year                 cleaned_name  \
# 2            2017           2017  2017                 #RealityHigh
# 4            2016           2016  2016                      1 Night
# 6            2023           2023  2023        10 Days of a Good Man
# 13           2011           2011  2011        12 Dates of Christmas
# 16           2015           2015  2015        12 Gifts Of Christmas
# ...           ...            ...   ...                          ...
# 7016         2024           2024  2024   Your Friend, Nate Bargatze
# 7018         2024           2024  2024                 Your Monster
# 7019         2023           2023  2023           Your Place or Mine
# 7021         2020           2020  2020  Yours Sincerely, Kanan Gill
# 7032         2018           2018  2018                         Zion
#
#                       search_url Classification date Year of production  ...  \
# 2                    realityhigh       9 August 2017      Not Specified  ...
# 4                        1-night        29 June 2017      Not Specified  ...
# 6               10-days-good-man        2 March 2023      Not Specified  ...
# 13            12-dates-christmas         31 May 2017      Not Specified  ...
# 16            12-gifts-christmas    31 December 2021      Not Specified  ...
# ...                          ...                 ...                ...  ...
# 7016   your-friend-nate-bargatze    23 December 2024      Not Specified  ...
# 7018                your-monster     25 October 2024               2024  ...
# 7019          your-place-or-mine    24 December 2022      Not Specified  ...
# 7021  yours-sincerely-kanan-gill       24 April 2020      Not Specified  ...
# 7032                        zion       9 August 2018      Not Specified  ...
#
#         nudity Developer Publisher Author Reason for Refused Classification  \
# 2         none      None      None   None                              None
# 4         none      None      None   None                              None
# 6     moderate      None      None   None                              None
# 13        none      None      None   None                              None
# 16        none      None      None   None                              None
# ...        ...       ...       ...    ...                               ...
# 7016      none      None      None   None                              None
# 7018      none      None      None   None                              None
# 7019      mild      None      None   None                              None
# 7021      none      None      None   None                              None
# 7032      mild      None      None   None                              None
#
#       outcome duration_num strong_count moderate_count  \
# 2     success        100.0            0              2
# 4     success         76.0            0              2
# 6     success        124.0            2              4
# 13    success         87.0            0              0
# 16    success         86.0            0              0
# ...       ...          ...          ...            ...
# 7016  success         64.0            0              0
# 7018  success        102.0            0              3
# 7019  success        110.0            0              1
# 7021  success         72.0            0              2
# 7032  success         12.0            0              0
#
#                       url_ending
# 2                    realityhigh
# 4                        1-night
# 6               10-days-good-man
# 13            12-dates-christmas
# 16            12-gifts-christmas
# ...                          ...
# 7016   your-friend-nate-bargatze
# 7018                your-monster
# 7019        your-place-or-mine-0
# 7021  yours-sincerely-kanan-gill
# 7032                        zion
#
# [1201 rows x 42 columns]

# %%
mask = df_w_ratings.duration_num.lt(220) \
    & np.logical_not(df_w_ratings['Category detail'].isin(outside_classifiers)) \
    & df_w_ratings.drug_use.isin(['strong', 'high'])
    # & (df_w_ratings.Classification.isin(['MA 15+']))
    # & (df_w_ratings.nudity.isin(['strong', 'high']) | df_w_ratings.drug_use.isin(['strong', 'high']))
    
    # & df_w_ratings.drug_use.isin(['moderate', 'strong', 'high']) \

df_w_ratings[mask][ratings_cols].sort_values(['strong_count']).iloc[30:]
# Out:
#                                              Name  \
# 1322                          Cocaine Bear (2023)
# 3717                  My Brother The Devil (2012)
# 276                      abcs-death-2          R 18+
# 891                           bliss-8          R 18+
# 1661                      dog-eat-dog          R 18+
# 1989                            filth          R 18+
# 2545                            horns          R 18+
# 5472                            end-1         MA 15+
# 5167                       abcs-death          R 18+
# 5071                 t2-trainspotting          R 18+
# 6351                 wolf-wall-street          R 18+
# 6403                            end-1         MA 15+
#
#                                         Consumer advice Category  \
# 1322  Strong blood and gore, animal attacks, violenc...    Films
# 3717      Strong violence, drug use and coarse language    Films
# 4024      Strong violence, coarse language and drug use    Films
# 3921    Strong crude sexual humour, drug use and nudity    Films
# 6280             Strong themes, drug use and sex scenes    Films
# 6314  Strong crude humour, sexual references, drug u...    Films
# 2731    Strong sex scenes, frequent drug use and nudity    Films
# 5491           Strong drug use, violence and sex scenes    Films
# 5110  Strong sexual references, coarse language and ...    Films
# 464              Strong drug themes and coarse language    Films
# 1123  Strong themes, violence, sexual violence and c...    Films
# 1607  Strong sex scenes, sexual references, themes, ...    Films
# 5529  Strong themes, sexual violence, drug use and c...    Films
# 5111  Strong drug use, crude humour, sexual referenc...    Films
# 4646                          High impact sexual themes    Films
# 5099  Strong themes, drug use, violence and coarse l...    Films
# 5094  Strong coarse language, sex scenes, nudity and...    Films
# 2416                               High impact drug use    Films
# 2996  Strong coarse language, violence, sex and drug...    Films
# 4841  Strong sex scenes, coarse language, drug use a...    Films
# 800   Strong drug themes, sexual references and viol...    Films
# 660   Strong sexual references, sex scenes, coarse l...    Films
# 2558  Strong coarse language, nudity, drug use, viol...    Films
# 4566  Strong crude sexual humour, coarse language an...    Films
# 1629  Strong sex scene, crude sexual references, nud...    Films
# 5927  Strong drug use, nudity, sex scene and coarse ...    Films
# 5924  Strong drug use, nudity, sex scene and coarse ...    Films
# 6081  Strong sexual references, violence, drug use a...    Films
# 3398  Strong horror violence, coarse language and dr...    Films
# 2684           High impact coarse language and drug use    Films
# 5502  Strong crude humour, sex, drug use and coarse ...    Films
# 640   Strong themes, sexualised imagery, violence, d...    Films
# 3493                  Strong themes and coarse language    Films
# 3384  Strong horror themes, bloody violence, drug us...    Films
# 3517                          High impact injury detail    Films
# 5651  Strong crude humour, sexual references, nudity...    Films
# 6980                        High impact horror violence    Films
# 276   High impact horror themes, violence, sexual vi...    Films
# 891   High impact themes, violence, drug use, sex an...    Films
# 1661         Brief depictions of actual sexual activity    Films
# 1989                             High impact sex scenes    Films
# 2545               High impact violence, blood and gore    Films
# 5472  Strong crude humour, coarse language, sexual r...    Films
# 5167     High impact sexual themes, violence and nudity    Films
# 5071   High impact themes, coarse language and drug use    Films
# 6351                High impact sex scenes and drug use    Films
# 6403  Strong crude humour, coarse language, sexual r...    Films
#
#                Category detail            Media type  \
# 1322         Public Exhibition                   DCP
# 3717          Film - Sale/Hire                   DVD
# 4024  Film - Public Exhibition                   DCP
# 3921  Film - Public Exhibition                   DCP
# 6280  Film - Public Exhibition                   DCP
# 6314  Film - Public Exhibition                   DCP
# 2731  Film - Public Exhibition                   DCP
# 5491          Film - Sale/Hire                   DVD
# 3717         107.0             3
# 4024         116.0             3
# 3921         105.0             3
# 6280         130.0             3
# 6314         101.0             3
# 2731         149.0             3
# 5491          98.0             3
# 5110         106.0             3
# 464          128.0             3
# 1123          86.0             4
# 1607         102.0             4
# 5529         104.0             4
# 5111         116.0             4
# 4646          80.0             4
# 5099         138.0             4
# 5094          88.0             4
# 2416          97.0             4
# 2996          99.0             4
# 4841         112.0             4
# 800          105.0             4
# 660           97.0             4
# 2558          93.0             4
# 4566          89.0             4
# 1629         102.0             4
# 5927         101.0             4
# 5924         101.0             4
# 6081         107.0             4
# 3398         100.0             4
# 2684         141.0             5
# 5502          98.0             5
# 640          189.0             5
# 3493          98.0             5
# 3384         121.0             5
# 3517         147.0             5
# 5651         101.0             5
# 6980         106.0             5
# 276          123.0             6
# 891           81.0             6
# 1661          89.0             6
# 1989          97.0             6
# 2545         138.0             6
# 5472         107.0             6
# 5167         129.0             6
# 5071         117.0             6
# 6351         179.0             6
# 6403         107.0             6

# %%
manual_acb_df = da.get_acb_film_ratings()

# %%
record_list = []
curr_df = manual_acb_df.iloc[-25:].copy()

for ii, url in enumerate(tqdm(curr_df['url'])):

    movie_info = {'movie': curr_df['movie'].iloc[ii]}

    if type(url) != str or 'http' not in url:
        record_list.append(movie_info)
        continue

    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.content, 'html.parser')

    # Extract metadata
    movie_info = get_metadata_table(soup, movie_info)

    # Find and iterate through 6 rows in classification table
    matrix = soup.find_all('li', class_='impact-matrix__item')

    # Check size of impact table matches known patterns
    if len(matrix) == 6:
        movie_info = get_matrix_results(matrix, movie_info)
    elif len(matrix) == 12:
        # ACB tables can be doubled up due to mistakes in data
        movie_info = get_matrix_results(matrix[::2], movie_info)

        if all(val == 'none' for key, val in movie_info.items() if key in md.full_cat_cols):
            movie_info = get_matrix_results(matrix[1::2], movie_info)

    else:
        logging.info(f'Skipped {movie_info["movie"]}')

    time.sleep(1)
    record_list.append(movie_info)

acb_check_df = pd.DataFrame(record_list)
# Out:
# 100%|██████████| 25/25 [00:42<00:00,  1.72s/it]

# %%
full_df = curr_df.merge(acb_check_df, on=['movie'], how='left', suffixes=('_man','_web'))

# %%
incorrect_cat = pd.concat([full_df[f'{cat}_man'].ne(full_df[f'{cat}_web']) for cat in md.full_cat_cols], axis=1).any(axis=1)
changed_cols = ['movie'] + [col + '_man' for col in md.full_cat_cols] + [col + '_web' for col in md.full_cat_cols]
full_df[incorrect_cat & full_df.themes_man.notna()][changed_cols]
# Out:
# Empty DataFrame
# Columns: [movie, themes_man, violence_man, language_man, drug_use_man, nudity_man, sex_man, themes_web, violence_web, language_web, drug_use_web, nudity_web, sex_web]
# Index: []

# %%
full_df[full_df['Consumer advice'].ne('Not Specified') & full_df.consumer_advice.str.lower().str.replace(',', '').ne(full_df['Consumer advice'].str.lower().str.replace(',', ''))][['movie', 'consumer_advice', 'Consumer advice']]
# Out:
# Empty DataFrame
# Columns: [movie, consumer_advice, Consumer advice]
# Index: []
