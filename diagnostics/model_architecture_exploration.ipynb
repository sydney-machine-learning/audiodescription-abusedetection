# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(asctime)s - %(message)s')

import pandas as pd
pd.options.mode.chained_assignment = None

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
device = torch.device('cuda')

from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix, ConfusionMatrixDisplay

from IPython.display import clear_output
clear_output()

from tabulate import tabulate
from tqdm import tqdm

from audiodescription_abusedetection import utils, plotting
from audiodescription_abusedetection import data_extraction as da
from audiodescription_abusedetection import extract_sem_representation as esr
from audiodescription_abusedetection import collect_model_results as cmr
from audiodescription_abusedetection import modelling as md

import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 22
#      19 from tabulate import tabulate
#      20 from tqdm import tqdm
# ---> 22 import utils
#      23 import data_extraction as da
#      24 import extract_sem_representation as esr
#
# ModuleNotFoundError: No module named 'utils'

# %%
df, ratings = cmr.get_text_and_ratings()
tfidf_params = {'min_df': 0.01, 'max_df': 0.9, 'ngram_range': (1, 3), 'strip_accents': 'ascii'}
log_reg_all_df = cmr.perform_baseline_log_reg(df, ratings, output_dir=md.results_dir, tfidf_params=tfidf_params)

log_reg_cat_df = log_reg_all_df.groupby(['cat', 'rep_type']).agg({'acc': 'mean', 'f1_macro': 'mean'}).reset_index()
log_reg_cat_df['f1_macro'] = log_reg_cat_df['f1_macro'].round(1)
log_reg_cat_df = md.apply_cat_order(log_reg_cat_df)
log_reg_cat_df['Category'] = log_reg_cat_df.cat.str.title().str.replace('_', ' ')

g = sns.barplot(
    data=log_reg_cat_df.rename(columns={'rep_type': 'Type'}),
    x='Category', y='f1_macro', hue='Type'
)
plt.ylabel('Macro F1')
g.axes.bar_label(g.axes.containers[0], fontsize=6)
g.axes.bar_label(g.axes.containers[2], fontsize=6)
sns.despine()
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Type', ncol=3)
plotting.savefig('Baseline Logistic Regression Performance')
plt.show()

# %%
models_top_1_df = md.agg_and_sort_cv_results('models', final_groupby='cat', top_n=1)
models_top_1_df
# Out:
#                                                model       cat    rep_type  \
# 0  cardiffnlp/twitter-roberta-large-sensitive-mul...  language  transcript
# 1  cardiffnlp/twitter-roberta-large-sensitive-mul...  violence  transcript
# 2  cardiffnlp/twitter-roberta-large-sensitive-mul...       sex  transcript
# 3  cardiffnlp/twitter-roberta-large-sensitive-mul...    themes  transcript
# 4  cardiffnlp/twitter-roberta-large-sensitive-mul...  drug_use  transcript
# 5  cardiffnlp/twitter-roberta-large-sensitive-mul...    nudity  transcript
#
#   packing_type pooling_strat classifier   f1_macro        acc     auroc
# 0       chunks     no-stride    Log Reg  72.403306  72.363636  0.925211
# 1   utterances        lhsCLS    Log Reg  66.356332  66.909091  0.872117
# 2       chunks     no-stride    Log Reg  62.759652  64.727273  0.874923
# 3       chunks        lhsCLS    Log Reg  57.387436  57.090909  0.839448
# 4   utterances        lhsCLS    Log Reg  55.659433  64.181818  0.812916
# ...

# %%
all_best_df = pd.read_parquet(md.sem_rep_metrics_fp + 'best.parquet')
all_best_df[all_best_df.model.eq(md.pooling_models[0]) & all_best_df.cat.eq('violence')] \
    .groupby(['rep_type', 'packing_type', 'pooling_strat', 'classifier']) \
        .agg({'f1_macro': 'mean'}) \
        .reset_index() \
        .sort_values('f1_macro', ascending=False)
# Out:
#       rep_type packing_type pooling_strat classifier   f1_macro
# 11  transcript   utterances        lhsCLS    Log Reg  66.621339
# 9   transcript       chunks     no-stride    Log Reg  65.175814
# 7   transcript       chunks        lhsCLS    Log Reg  63.406085
# 5    narration       chunks     no-stride    Log Reg  62.357050
# 3     dialogue   utterances        lhsCLS    Log Reg  61.183543
# 8   transcript       chunks     no-stride       LSVM  60.241598
# 4    narration       chunks     no-stride       LSVM  59.286751
# 1     dialogue       chunks     no-stride    Log Reg  58.669939
# 6   transcript       chunks        lhsCLS       LSVM  58.597358
# 10  transcript   utterances        lhsCLS       LSVM  57.976048
# 2     dialogue   utterances        lhsCLS       LSVM  55.054540
# 0     dialogue       chunks     no-stride       LSVM  52.983789

# %%
cleaned_initial_models_df = md.agg_and_sort_cv_results('models', final_groupby='cat', top_n=1).drop(columns=['auroc', 'classifier'])
cleaned_initial_models_df['model'] = np.select(
    [cleaned_initial_models_df.model.eq(x) for x in md.pooling_models],
    md.abb_pooling_model_names,
    default=''
)
cleaned_initial_models_df['pooling_strat'] = np.where(cleaned_initial_models_df['pooling_strat'].eq('no-stride'), '0', '128')
cleaned_initial_models_df = md.apply_cat_order(cleaned_initial_models_df)
cleaned_initial_models_df['cat'] = cleaned_initial_models_df.cat.str.title().str.replace('_', ' ')
cleaned_initial_models_df.columns = ['Model', 'Category', 'Text Type', 'Packing', 'Token Stride', 'Macro F1', 'Accuracy']

latex_table = tabulate(cleaned_initial_models_df, headers='keys', tablefmt='latex', floatfmt=".3g", showindex=False)
with open(os.path.join(plotting.output_dir, 'First Pass Models Table.tex'), 'w') as fileobj:
    fileobj.write(latex_table)

# %%
raw_models_df = pd.read_parquet(md.sem_rep_metrics_fp + 'models.parquet')

models_df = raw_models_df[~(raw_models_df.pooling_strat.eq('lhsCLS') & raw_models_df.packing_type.eq('chunks'))] \
    .groupby(['model', 'rep_type', 'packing_type']) \
    .agg({'f1_macro': 'mean'}) \
    .reset_index()

models_df['f1_macro'] = models_df['f1_macro'].round(1)

models_df['Configuration'] = np.select(
    [models_df.rep_type.eq(x) & models_df.packing_type.eq(y) for x in md.rep_types for y in md.packing_types],
    [f'{x.title()}\n{y.title()}' for x in md.rep_types for y in md.packing_types],
    default=''
) 

models_df['model_abb'] = np.select(
    [models_df.model.eq(x) for x in md.pooling_models],
    md.abb_pooling_model_names,
    default=''
)

models_df = md.apply_model_order(models_df).sort_values(['model', 'Configuration'])
g = sns.barplot(
    data=models_df[models_df.rep_type.ne('narration')], #kind='bar',
    x='Configuration', y='f1_macro', hue='model_abb', errorbar=None,
    # height=2.5, aspect=1.4
)
plt.ylabel('Macro F1')
plt.xlabel('Configuration')

plt.tight_layout()
sns.despine()

g.axes.bar_label(g.axes.containers[0], fontsize=7)

plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Model Abbreviation', ncol=3)
plotting.savefig('Initial Model Results by Configuration')
plt.show()

# %%
models_df[models_df.model.isin(md.pooling_models[2:]) & models_df.rep_type.eq('transcript')]
# Out:
#                                                model    rep_type packing_type  \
# 10         cardiffnlp/twitter-roberta-base-offensive  transcript       chunks
# 11         cardiffnlp/twitter-roberta-base-offensive  transcript   utterances
# 16  cardiffnlp/twitter-roberta-base-sentiment-latest  transcript       chunks
# 17  cardiffnlp/twitter-roberta-base-sentiment-latest  transcript   utterances
# 34          mrm8488/t5-base-finetuned-imdb-sentiment  transcript       chunks
# 35          mrm8488/t5-base-finetuned-imdb-sentiment  transcript   utterances
# 4           NemoraAi/modernbert-chat-moderation-X-V2  transcript       chunks
# 5           NemoraAi/modernbert-chat-moderation-X-V2  transcript   utterances
#
#     f1_macro           Configuration          model_abb
# 10      38.1      Transcript\nChunks          Offensive
# 11      53.8  Transcript\nUtterances          Offensive
# 16      34.6      Transcript\nChunks  Twitter Sentiment
# ...

# %%
pca_df = md.agg_and_sort_cv_results('pca', final_groupby=['model', 'pca_setting'], agg_groupby=['model', 'cat', 'pca_setting'], top_n=1) \
    .sort_values(['model', 'f1_macro'], ascending=False)

pca_df['baseline_f1'] = pca_df['model'].map(pca_df[pca_df['pca_setting'] == 'original'].set_index('model')['f1_macro'])
pca_df['pca_impact'] = (pca_df['f1_macro'] - pca_df['baseline_f1']).round(1)

pca_df = pca_df[pca_df.model.isin(md.pooling_models[:3]) & pca_df.pca_setting.ne('original')]
pca_df['PCA Setting'] = np.select(
    [pca_df.pca_setting.eq(x) for x in ['None', '0.8', '0.95', '32', '64', 'original']],
    ['All Components', '80% Var. Expl.', '95% Var. Expl.', '32 Components', '64 Components', 'No PCA'],
    default=''
)

pca_df['Model'] = np.select(
    [pca_df.model.eq(x) for x in md.pooling_models[:3]],
    md.abb_pooling_model_names[:3],
    default=''
)

g = sns.barplot(pca_df, x='Model', y='pca_impact', hue='PCA Setting')
g.axes.bar_label(g.axes.containers[0])
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='PCA Strategy', ncol=3)
sns.despine()
plt.ylabel('Macro F1 Change')
plt.tight_layout()
plotting.savefig('PCA Impact')
plt.show()

# %%
cls_pooling_df_list = []
for cls_pooling in ['CLS-1', 'CLS-2', 'CLS-Max', 'CLS-Mean']:
    curr_df = pd.read_parquet(f'{md.sem_rep_metrics_fp}{cls_pooling}.parquet') \
        .groupby(['model', 'cat', 'rep_type', 'packing_type', 'classifier']) \
        .agg({'f1_macro': 'mean', 'acc': 'mean', 'auroc': 'mean'}) \
        .reset_index() \
        .sort_values(['f1_macro'], ascending=False) \
        .groupby('cat') \
        .head(1).reset_index(drop=True)
    
    curr_df['pooling'] = cls_pooling

    cls_pooling_df_list.append(curr_df)

# Add CLS-All
models_top_1_df['pooling'] = 'CLS-All'
cls_pooling_df_list.append(models_top_1_df)

cls_pooling_df = pd.concat(cls_pooling_df_list).sort_values(['cat', 'f1_macro'], ascending=[True, False])

cls_pooling_df['baseline_f1'] = cls_pooling_df['cat'].map(cls_pooling_df[cls_pooling_df['pooling'] == 'CLS-All'].set_index('cat')['f1_macro'])
cls_pooling_df['cls_impact'] = (cls_pooling_df['f1_macro'] - cls_pooling_df['baseline_f1']).round(1)

cls_pooling_df = cls_pooling_df[cls_pooling_df.pooling.ne('CLS-All')]

# cls_pooling_df['cls_impact'] = cls_pooling_df['f1_macro'] - cls_pooling_df.groupby('pooling').f1_macro.transform('min')
cls_pooling_df['Category'] = cls_pooling_df.cat.str.title().str.replace('_', ' ')
cls_pooling_df = md.apply_cat_order(cls_pooling_df)

g = sns.barplot(
    data=cls_pooling_df,
    x='Category', y='cls_impact', hue='pooling',
    errorbar=None
)
plt.ylabel('Macro F1')
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Pooling Strategy', ncol=4)
plotting.savefig('CLS Ablative Comparison')
plt.show()

# %%
emotion_df = md.agg_and_sort_cv_results('emotion', agg_groupby=['model', 'cat', 'rep_type', 'packing_type', 'pooling_strat', 'classifier', 'hypothesis'], final_groupby=['cat', 'hypothesis'], top_n=1)
emotion_df
# Out:
#                                                model       cat    rep_type  \
# 0  cardiffnlp/twitter-roberta-large-sensitive-mul...  language    dialogue
# 1  cardiffnlp/twitter-roberta-large-sensitive-mul...  violence   narration
# 2  cardiffnlp/twitter-roberta-large-sensitive-mul...       sex  transcript
# 3    cardiffnlp/twitter-roberta-large-emotion-latest    themes  transcript
# 4  cardiffnlp/twitter-roberta-large-sensitive-mul...  drug_use  transcript
# 5  cardiffnlp/twitter-roberta-large-sensitive-mul...    nudity   narration
#
#   packing_type pooling_strat classifier hypothesis   f1_macro        acc  \
# 0       chunks        lhsCLS    Log Reg    emotion  73.590094  74.000000
# 1       chunks     no-stride    Log Reg    emotion  63.950921  64.181818
# 2       chunks        lhsCLS    Log Reg    emotion  62.424176  64.727273
# 3       chunks     no-stride    Log Reg    emotion  59.435063  60.363636
# 4       chunks        lhsCLS    Log Reg    emotion  58.424269  69.636364
# ...

# %%
best_rep_type_by_cat_df = md.agg_and_sort_cv_results('best', agg_groupby=['model', 'cat', 'rep_type', 'packing_type', 'pooling_strat', 'classifier'], final_groupby=['cat', 'rep_type'], top_n=1)
best_rep_type_by_cat_df = md.apply_cat_order(best_rep_type_by_cat_df)
best_rep_type_by_cat_df['f1_macro'] = best_rep_type_by_cat_df['f1_macro'].round(1)
best_rep_type_by_cat_df['Category'] = best_rep_type_by_cat_df.cat.str.title().str.replace('_', ' ')
g = sns.barplot(best_rep_type_by_cat_df, y='f1_macro', x='Category', hue='rep_type', hue_order=['dialogue', 'narration', 'transcript'])
g.axes.bar_label(g.axes.containers[0], fontsize=6)
g.axes.bar_label(g.axes.containers[2], fontsize=6)
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Text Type', ncol=3)
plt.ylabel('Macro F1')
sns.despine()
plotting.savefig('Best Text Types by Category')

# %%
best_agg_df = md.agg_and_sort_cv_results('best', agg_groupby=['model', 'cat', 'rep_type', 'packing_type', 'pooling_strat', 'classifier'], final_groupby=['cat'], top_n=1)
md.apply_cat_order(best_agg_df).round(1)
# Out:
#                                                model       cat    rep_type  \
# 3  cardiffnlp/twitter-roberta-large-sensitive-mul...    themes  transcript
# 1  cardiffnlp/twitter-roberta-large-sensitive-mul...  violence  transcript
# 0  cardiffnlp/twitter-roberta-large-sensitive-mul...  language  transcript
# 4  cardiffnlp/twitter-roberta-large-sensitive-mul...  drug_use  transcript
# 5  cardiffnlp/twitter-roberta-large-sensitive-mul...    nudity  transcript
# 2  cardiffnlp/twitter-roberta-large-sensitive-mul...       sex  transcript
#
#   packing_type pooling_strat classifier  f1_macro  auroc   acc
# 3       chunks        lhsCLS    Log Reg      57.2    0.8  56.9
# 1   utterances        lhsCLS    Log Reg      66.6    0.9  67.2
# 0       chunks     no-stride    Log Reg      72.6    0.9  72.4
# 4       chunks        lhsCLS       LSVM      55.7    NaN  68.2
# 5       chunks     no-stride    Log Reg      49.3    0.8  58.5
# 2       chunks     no-stride    Log Reg      63.0    0.9  65.0

# %%
log_reg_cat_df.groupby('cat').f1_macro.max().round(1).values
# Out:
# /tmp/ipykernel_184505/117692463.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   log_reg_cat_df.groupby('cat').f1_macro.max().round(1).values
# array([43.8, 53.8, 57.5, 42.1, 31.5, 48.8])

# %%
prev_models_df = pd.read_csv('previous_models.csv')

titles = [x.title().replace('_', ' ') for x in md.full_cat_cols]
prev_models_df.loc[0, titles] = log_reg_cat_df.groupby('cat').f1_macro.max().round(1).values
prev_models_df.loc[1, titles] = md.apply_cat_order(best_agg_df).groupby('cat').f1_macro.max().round(1).values

for col in prev_models_df.columns[3:10]:
    prev_models_df[col] = prev_models_df[col].apply(lambda x: r"\textbf{" + str(x) + "}" if x == prev_models_df[col].max() else str(x)).astype(str)

prev_models_df = prev_models_df.replace('nan', '')

latex_table = tabulate(prev_models_df, headers='keys', tablefmt='latex_raw', showindex=False, missingval='')
with open(os.path.join(plotting.output_dir, 'Previous_Models.tex'), 'w') as fileobj:
    fileobj.write(latex_table)
prev_models_df
# Out:
# /tmp/ipykernel_184505/3425409119.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   prev_models_df.loc[0, titles] = log_reg_cat_df.groupby('cat').f1_macro.max().round(1).values
# /tmp/ipykernel_184505/3425409119.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   prev_models_df.loc[1, titles] = md.apply_cat_order(best_agg_df).groupby('cat').f1_macro.max().round(1).values
#                          Method Dataset Size  # Severity Categories  \
# 0  Baseline Logistic Regression          550                      4
# 1              Best Performance          550                      4
# ...

# %%
row_level_df_list = []
for ii in range(5):
    row_level_df_list.append(pd.read_parquet(md.row_level_classification_fp + f'best-{ii}.parquet'))
    row_level_df_list[-1]['batch_num'] = ii

row_level_df = pd.concat(row_level_df_list)

# %%
row_level_df['pred_correct'] = row_level_df['true'].eq(row_level_df['pred']).astype(int) * 100
freq_pred_df = row_level_df.groupby('movie').agg({'pred_correct': 'mean'}).reset_index().sort_values('pred_correct').round(1).reset_index(drop=True)
freq_pred_df.columns = ['Movie', 'Correct (%)']
# freq_pred_df = pd.concat([freq_pred_df.iloc[:10], freq_pred_df.iloc[-10:]], axis=0)

# latex_table = tabulate(freq_pred_df, headers='keys', tablefmt='latex', floatfmt=".3g", showindex=False)
# with open(os.path.join(plotting.output_dir, 'Easiest and Most Difficult Films.tex'), 'w') as fileobj:
#     fileobj.write(latex_table)

freq_pred_df
# Out:
#                                Movie  Correct (%)
# 0                      The Big Short         14.8
# 1                        Guest House         16.7
# 2                        Oppenheimer         18.5
# 3                       Patriots Day         20.4
# 4                 The Wedding Ringer         22.2
# ..                               ...          ...
# 545                 Dater'S Handbook         96.3
# 546                    Emma'S Chance         98.1
# 547  Alice Through The Looking Glass         98.1
# 548                    The Lion King         98.1
# 549             Beauty And The Beast        100.0
#
# [550 rows x 2 columns]

# %%
acb_df = da.get_acb_film_ratings()
for col in md.full_cat_cols:
    acb_df[col + '_int'] = md.convert_col_to_ordinal(acb_df[col], compact=False)

acb_df['movie'] = acb_df['movie'].str.replace(':', '').str.replace('-', ' ').str.replace('.', '').str.title()
rating_freq_df = freq_pred_df.merge(acb_df, left_on='Movie', right_on='movie', how='left').drop(columns=['url'])
rating_freq_df['Classification'] = np.select(
    [rating_freq_df[md.full_cat_cols].isin(x).any(axis=1) for x in [['high'], ['strong'], ['moderate'], ['mild'], ['none', 'very mild']]],
    md.classifications[::-1],
    default='G'
)
rating_freq_df['Average Severity Level'] = rating_freq_df[[col + '_int' for col in md.full_cat_cols]].mean(axis=1)

g = sns.scatterplot(rating_freq_df, x='Correct (%)', y='Average Severity Level', hue='Classification', palette=plotting.full_acb_palette[1:], hue_order=md.classifications)

plt.xlabel('Film Categories Classified Correctly (%)')
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Classification', ncol=5)
sns.despine()
plotting.savefig('Classification Accuracy Against Severity Level')
plt.show()

# %%
small_df = rating_freq_df.groupby('Classification', group_keys=False).apply(lambda x: x.nsmallest(4, 'Correct (%)'), include_groups=True)
large_df = rating_freq_df.groupby('Classification', group_keys=False).apply(lambda x: x.nlargest(4, 'Correct (%)'), include_groups=True)
clear_output()
outliers_df = pd.concat([small_df, large_df]).round(1)
outliers_df = outliers_df[outliers_df.Classification.isin(['PG', 'M', 'MA 15+'])].sort_values('Correct (%)')
outliers_df['max_sev'] = np.select([outliers_df.Classification.eq(x) for x in ['PG', 'M', 'MA 15+']], [2, 3, 4])
outliers_df['perc_sev'] = (outliers_df['Average Severity Level'] / outliers_df['max_sev']).round(2)
outliers_df[['Movie', 'Correct (%)', 'Classification', 'Average Severity Level', 'perc_sev']]
# Out:
#                                            Movie  Correct (%) Classification  \
# 0                                  The Big Short         14.8              M
# 1                                    Guest House         16.7         MA 15+
# 2                                    Oppenheimer         18.5         MA 15+
# 3                                   Patriots Day         20.4              M
# 4                             The Wedding Ringer         22.2         MA 15+
# 5                    A Futile And Stupid Gesture         24.1         MA 15+
# 14                       Men, Women And Children         27.8              M
# 13                                    Patti Cake         27.8              M
# 12                              The Confirmation         27.8             PG
# 26                  Johnny English Strikes Again         33.3             PG
# 100                                   Dad'S Army         44.4             PG
# ...

# %%
row_level_df = pd.read_parquet(md.row_level_classification_fp + 'best-0.parquet')

filtered_row_level_df_list = []

for cat in md.full_cat_cols:
    best_config = best_agg_df[best_agg_df.cat.eq(cat)].iloc[0]
    curr_mask = row_level_df.cat.eq(cat) \
        & row_level_df.model.eq(best_config['model']) \
        & row_level_df.rep_type.eq(best_config['rep_type']) \
        & row_level_df.packing_type.eq(best_config['packing_type']) \
        & row_level_df.pooling_strat.eq(best_config['pooling_strat'])
        
    filtered_row_level_df_list.append(row_level_df[curr_mask])

filtered_row_level_df = pd.concat(filtered_row_level_df_list)

fig, ax = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True)

for ii, cat in enumerate(md.full_cat_cols):
    curr_cat_df = filtered_row_level_df[filtered_row_level_df.cat.eq(cat)]
    mat = confusion_matrix(curr_cat_df['true'].values, curr_cat_df['pred'].values)
    disp = ConfusionMatrixDisplay(mat)
    curr_ax = ax[ii // 3][ii % 3]
    disp.plot(ax=curr_ax, colorbar=False)
    curr_ax.set_xlabel('')
    curr_ax.set_ylabel('')

    curr_ax.set_title(cat.title().replace('_', ' '))
    
fig.text(0.5, 0, 'Predicted Label', ha='center')
fig.text(0, 0.5, 'True Label', va='center', rotation='vertical')
plt.tight_layout()
plotting.savefig('Top Models Confusion Matrices')
plt.show()

# %%
df_list = []
for ii in range(30):
    df_list.append(pd.read_parquet(md.sem_rep_metrics_fp + f'variance-{ii}.parquet'))
var_df = pd.concat(df_list)

var_df['batch_num'] = np.array([[ii] * int(var_df.shape[0] / 10) for ii in range(10)]).flatten()

cv_var_df = var_df.groupby(['cat', 'batch_num']) \
    .agg({'f1_macro': 'mean'}) \
    .reset_index()

cv_var_df['Grouping'] = '5-CV Batch Avgs'
var_df['Grouping'] = 'All Experiments'

range_var_df = pd.concat([var_df, cv_var_df])
range_var_df = md.apply_cat_order(range_var_df)
range_var_df['Category'] = range_var_df['cat'].str.title().str.replace('_', ' ')

g = sns.boxplot(range_var_df, x='Category', y='f1_macro', hue='Grouping')
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Grouping', ncol=2)

plt.ylabel('Macro F1')
plotting.savefig('Macro F1 Variance')
plt.show()

# %%
agg_groupby = ['model', 'rep_type', 'packing_type', 'pooling_strat', 'classifier']

overall_ratings_df = pd.read_parquet(md.sem_rep_metrics_fp + 'overall-rating.parquet') \
    .groupby(agg_groupby) \
    .agg({'f1_macro': 'mean', 'acc': 'mean', 'f1_weighted': 'mean'}) \
    .reset_index()
    
overall_ratings_df
# Out:
#                                                model    rep_type packing_type  \
# 0  cardiffnlp/twitter-roberta-large-sensitive-mul...  transcript       chunks
#
#   pooling_strat classifier   f1_macro        acc  f1_weighted
# 0     no-stride    Log Reg  70.446668  80.939394    80.872948

# %%
agg_groupby = ['model', 'rep_type', 'packing_type', 'pooling_strat', 'classifier']

overall_ratings_df = pd.read_parquet(md.sem_rep_metrics_fp + 'overall-rating-dialogue.parquet') \
    .groupby(agg_groupby) \
    .agg({'f1_macro': 'mean', 'acc': 'mean', 'f1_weighted': 'mean'}) \
    .reset_index()
    
overall_ratings_df
# Out:
#                                                model  rep_type packing_type  \
# 0  cardiffnlp/twitter-roberta-large-sensitive-mul...  dialogue       chunks
# 1  cardiffnlp/twitter-roberta-large-sensitive-mul...  dialogue   utterances
#
#   pooling_strat classifier   f1_macro        acc  f1_weighted
# 0        lhsCLS    Log Reg  64.028332  74.787879    75.171944
# 1        lhsCLS    Log Reg  65.846450  77.696970    78.123841

# %%
import pandas as pd
import os
import modelling as md
import matplotlib.pyplot as plt
import plotting
import seaborn as sns

# %%
df = pd.read_parquet(os.path.join(md.results_dir, 'film_segment_classification.parquet'))

seg_counts_df = df.groupby(['cat', 'rep_type', 'pred']) \
  .size().reset_index(name='count') \
  .sort_values(['cat', 'rep_type', 'pred'])

dialogue_df = seg_counts_df[seg_counts_df.rep_type.eq('dialogue')].drop(columns='rep_type')
dialogue_df['perc'] = dialogue_df.groupby('cat')['count'].transform(lambda x: x / x.sum() * 100)

transcript_df = seg_counts_df[seg_counts_df.rep_type.eq('transcript')].drop(columns='rep_type')
transcript_df['perc'] = transcript_df.groupby('cat')['count'].transform(lambda x: x / x.sum() * 100)

for cat in md.full_cat_cols:
    for ii in range(4):
        if (transcript_df.pred.eq(ii) & transcript_df.cat.eq(cat)).sum() == 0:
            transcript_df = pd.concat([transcript_df, pd.DataFrame([{'cat': cat, 'pred': ii, 'count': 0, 'perc': 0.0}])])
        if (dialogue_df.pred.eq(ii) & dialogue_df.cat.eq(cat)).sum() == 0:
            dialogue_df = pd.concat([dialogue_df, pd.DataFrame([{'cat': cat, 'pred': ii, 'count': 0, 'perc': 0.0}])])

transcript_df = transcript_df.sort_values(['cat', 'pred']).reset_index(drop=True)
dialogue_df = dialogue_df.sort_values(['cat', 'pred']).reset_index(drop=True)

transcript_df['change_in_percs'] = transcript_df['perc'] - dialogue_df['perc']

# %%
transcript_df = md.apply_cat_order(transcript_df)
transcript_df['Severity Level'] = transcript_df['pred']
transcript_df['Category'] = transcript_df['cat'].str.replace('_', ' ').str.title()
g = sns.barplot(transcript_df, y='change_in_percs', x = 'Category', hue='Severity Level')
plt.ylabel('Absolute Change in Percentage (%)')
txt_labels = ['Very Mild or None', 'Mild', 'Moderate', 'Strong or High']
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Severity Level', ncol=4, txt_labels=txt_labels)

# %%
dialogue_df = pd.read_parquet(os.path.join(md.results_dir, 'dialogue_utterances_film_segment_classification.parquet'))
transcript_df = pd.read_parquet(os.path.join(md.results_dir, 'transcript_utterances_film_segment_classification.parquet'))
df = pd.concat([dialogue_df, transcript_df])

seg_counts_df = df.groupby(['cat', 'rep_type', 'pred']) \
  .size().reset_index(name='count') \
  .sort_values(['cat', 'rep_type', 'pred'])

dialogue_df = seg_counts_df[seg_counts_df.rep_type.eq('dialogue')].drop(columns='rep_type')
dialogue_df['perc'] = dialogue_df.groupby('cat')['count'].transform(lambda x: x / x.sum() * 100)

transcript_df = seg_counts_df[seg_counts_df.rep_type.eq('transcript')].drop(columns='rep_type')
transcript_df['perc'] = transcript_df.groupby('cat')['count'].transform(lambda x: x / x.sum() * 100)

for cat in md.full_cat_cols:
    for ii in range(4):
        if (transcript_df.pred.eq(ii) & transcript_df.cat.eq(cat)).sum() == 0:
            transcript_df = pd.concat([transcript_df, pd.DataFrame([{'cat': cat, 'pred': ii, 'count': 0, 'perc': 0.0}])])
        if (dialogue_df.pred.eq(ii) & dialogue_df.cat.eq(cat)).sum() == 0:
            dialogue_df = pd.concat([dialogue_df, pd.DataFrame([{'cat': cat, 'pred': ii, 'count': 0, 'perc': 0.0}])])

transcript_df = transcript_df.sort_values(['cat', 'pred']).reset_index(drop=True)
dialogue_df = dialogue_df.sort_values(['cat', 'pred']).reset_index(drop=True)

transcript_df['change_in_percs'] = transcript_df['perc'] - dialogue_df['perc']

# %%
transcript_df = md.apply_cat_order(transcript_df)
transcript_df['Severity Level'] = transcript_df['pred']
transcript_df['Category'] = transcript_df['cat'].str.replace('_', ' ').str.title()
g = sns.barplot(transcript_df, y='change_in_percs', x = 'Category', hue='Severity Level')
plt.ylabel('Absolute Change in Percentage (%)')
txt_labels = ['Very Mild or None', 'Mild', 'Moderate', 'Strong or High']
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Severity Level', ncol=4, txt_labels=txt_labels)
plotting.savefig('Perc Change in Segment Severity Prediction')

# %%
dialogue_df = pd.read_parquet(os.path.join(md.results_dir, 'dialogue_utterances_film_segment_classification.parquet'))
transcript_df = pd.read_parquet(os.path.join(md.results_dir, 'transcript_utterances_film_segment_classification.parquet'))
df = pd.concat([dialogue_df, transcript_df])

seg_counts_df = df.groupby(['cat', 'rep_type', 'pred']) \
  .size().reset_index(name='count') \
  .sort_values(['cat', 'rep_type', 'pred'])

dialogue_df = seg_counts_df[seg_counts_df.rep_type.eq('dialogue')].drop(columns='rep_type')

transcript_df = seg_counts_df[seg_counts_df.rep_type.eq('transcript')].drop(columns='rep_type')

for cat in md.full_cat_cols:
    for ii in range(4):
        if (transcript_df.pred.eq(ii) & transcript_df.cat.eq(cat)).sum() == 0:
            transcript_df = pd.concat([transcript_df, pd.DataFrame([{'cat': cat, 'pred': ii, 'count': 0}])])
        if (dialogue_df.pred.eq(ii) & dialogue_df.cat.eq(cat)).sum() == 0:
            dialogue_df = pd.concat([dialogue_df, pd.DataFrame([{'cat': cat, 'pred': ii, 'count': 0}])])

transcript_df = transcript_df.sort_values(['cat', 'pred']).reset_index(drop=True)
dialogue_df = dialogue_df.sort_values(['cat', 'pred']).reset_index(drop=True)

transcript_df['change_count'] = (transcript_df['count'] - dialogue_df['count']) / 10000

# %%
classifier_df = md.agg_and_sort_cv_results('classifier', agg_groupby=['model', 'cat', 'rep_type', 'packing_type', 'pooling_strat', 'classifier'], final_groupby=['cat', 'classifier'], top_n=1)
classifier_df = md.apply_cat_order(classifier_df)
classifier_df['f1_macro'] = classifier_df['f1_macro'].round(1)
classifier_df['Category'] = classifier_df.cat.str.title().str.replace('_', ' ')
g = sns.barplot(classifier_df, y='f1_macro', x='Category', hue='classifier')
g.axes.bar_label(g.axes.containers[0], fontsize=6)
g.axes.bar_label(g.axes.containers[2], fontsize=6)
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Text Type', ncol=3)
plt.ylabel('Macro F1')
sns.despine()
plotting.savefig('Classifier Comparison')

# %%
md.agg_and_sort_cv_results('classifier')
# Out:
#                                                 model       cat    rep_type  \
# 3   cardiffnlp/twitter-roberta-large-sensitive-mul...  language  transcript
# 5   cardiffnlp/twitter-roberta-large-sensitive-mul...  language  transcript
# 15  cardiffnlp/twitter-roberta-large-sensitive-mul...  violence  transcript
# 9   cardiffnlp/twitter-roberta-large-sensitive-mul...       sex  transcript
# 0   cardiffnlp/twitter-roberta-large-sensitive-mul...  drug_use  transcript
# 11  cardiffnlp/twitter-roberta-large-sensitive-mul...       sex  transcript
# 17  cardiffnlp/twitter-roberta-large-sensitive-mul...  violence  transcript
# 12  cardiffnlp/twitter-roberta-large-sensitive-mul...    themes  transcript
# 14  cardiffnlp/twitter-roberta-large-sensitive-mul...    themes  transcript
# 16  cardiffnlp/twitter-roberta-large-sensitive-mul...  violence  transcript
# 2   cardiffnlp/twitter-roberta-large-sensitive-mul...  drug_use  transcript
# ...

# %%
transcript_df = md.apply_cat_order(transcript_df)
transcript_df['Severity Level'] = transcript_df['pred']
transcript_df['Category'] = transcript_df['cat'].str.replace('_', ' ').str.title()
g = sns.barplot(transcript_df, y='change_count', x = 'Category', hue='Severity Level')
plt.ylabel('Change in Predictions (10,000s)')
txt_labels = ['Very Mild or None', 'Mild', 'Moderate', 'Strong or High']
plotting.place_legend_ontop_of_graph(g, is_catplot=False, legend_title='Severity Level', ncol=2, txt_labels=txt_labels)
plotting.savefig('Abs Change in Segment Severity Prediction')
